# %% [markdown]
# <h1><center> Assignment 1: EDA United Nations General Debate Corpus  </center></h1>
#
# We are now going to give the first steps into exploring the United Nations General Debate Corpus. <span style="color:red">This dataset will be used in Group Assignment I (due date, Monday 3 October, 23:59)</span>. It is expected that you will pose a questions about the dataset, explore it, and combine it with other datasets (e.g., the Happiness Report 2022 that we've been using, or the International Trade Dataset).
#
# We will use the *the UN General Debate Corpus (UNGDC)*, which introduces the corpus of texts of UN General Debate statements from 1970 (Session 25) to 2020 (Session 75). More info [here](https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/0TJX8Y). Make sure to download the file <code>UNGDC_1970-2020.tar.gz</code> and extract the folder <code>TXT/</code> to the same directory as the current Jupyter notebook. You are also advised to collect and pre-process more recent speeches data (e.g. [session 76](https://gadebate.un.org/generaldebate76/en/))
#
# Notice that the 77th session of the UN General Assembly - where the 2022 debates will happen - will occur in 14-30 September 2021, precisely during the time you'll be working in Assignment 1. More info [here](https://www.un.org/en/ga/77/meetings/).
#
# You might find useful to have a dataset with the full name and 3-code description of countries. You can find that date [here](https://unstats.un.org/unsd/methodology/m49/overview/). Download the correspondig CSV file (named 'UNSD — Methodology.csv') and place it into the same folder as this notebook.
#
# We will start by loading the speeches text to a table:

# %%
import os
import numpy as np
import pandas as pd

sessions = np.arange(25, 76) # Why?
data = []

for session in sessions:
    directory = "./TXT/Session " + str(session) + " - " + str(1945 + session)
    for filename in os.listdir(directory):
        f = open(os.path.join(directory, filename))
        if filename[0] == ".": #ignore hidden files
            continue
        splt = filename.split("_")
        data.append([session, 1945 + session, splt[0], f.read()])


df_speech = pd.DataFrame(data, columns=['Session','Year','ISO-alpha3 Code','Speech'])

df_speech.tail()
# Out:
#       Session  Year ISO-alpha3 Code  \
# 8476       75  2020             HRV
# 8477       75  2020             GAB
# 8478       75  2020             MCO
# 8479       75  2020             AND
# 8480       75  2020             BHR
#
#                                                  Speech
# 8476  Mr President, Excellencies\nAll protocol obser...
# 8477  Mr. President, Majesties,\nLadies and Gentleme...
# 8478  Mr. President of the General Assembly,\nMr. Se...
# 8479  Mr. President,\nMr. Secretary General,\nYour E...
# 8480  In the name of Allah, the most gracious, the m...

# %% [markdown]
# Download the 'UNSD — Methodology.csv' ([link](https://unstats.un.org/unsd/methodology/m49/overview/)) file and and try to load it. Call the resulting dataframe 'df_codes'.
# Please check what is the separator used. Why is that separator used?

# %%
df_codes = pd.read_csv("UNSD — Methodology.csv", delimiter=';')
df_codes.head()
# Use ; as delimiter, because it is a CSV file.
# Out:
#    Global Code Global Name  Region Code Region Name  Sub-region Code  \
# 0            1       World          2.0      Africa             15.0
# 1            1       World          2.0      Africa             15.0
# 2            1       World          2.0      Africa             15.0
# 3            1       World          2.0      Africa             15.0
# 4            1       World          2.0      Africa             15.0
#
#    Sub-region Name  Intermediate Region Code Intermediate Region Name  \
# 0  Northern Africa                       NaN                      NaN
# 1  Northern Africa                       NaN                      NaN
# 2  Northern Africa                       NaN                      NaN
# 3  Northern Africa                       NaN                      NaN
# 4  Northern Africa                       NaN                      NaN
#
#   Country or Area  M49 Code ISO-alpha2 Code ISO-alpha3 Code  \
# 0         Algeria        12              DZ             DZA
# 1           Egypt       818              EG             EGY
# 2           Libya       434              LY             LBY
# 3         Morocco       504              MA             MAR
# 4           Sudan       729              SD             SDN
#
#   Least Developed Countries (LDC) Land Locked Developing Countries (LLDC)  \
# 0                             NaN                                     NaN
# 1                             NaN                                     NaN
# 2                             NaN                                     NaN
# 3                             NaN                                     NaN
# 4                               x                                     NaN
#
#   Small Island Developing States (SIDS)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN

# %% [markdown]
# **Q1: Can you create a merged DataFrame — merge between df_codes and df_speech according to ISO-alpha3 and composed of columns \["Country or Area", "Region Name","Sub-region Name", "ISO-alpha3 Code","Least Developed Countries (LDC)", "Session", "Year", "Speech"\]? It would be convinient to have index as (Year, 'ISO-alpha3 Code')**

# %%
df_un_merged = df_speech.merge(df_codes)

# reorder
df_un_merged[["Country or Area", "Region Name","Sub-region Name", "ISO-alpha3 Code","Least Developed Countries (LDC)", "Session", "Year", "Speech"]]

df_un_merged = df_un_merged.set_index(["Year", "ISO-alpha3 Code"])

df_un_merged.head()
# Out:
#                       Session  \
# Year ISO-alpha3 Code
# 1970 AUT                   25
# 1971 AUT                   26
# 1972 AUT                   27
# 1973 AUT                   28
# 1974 AUT                   29
#
#                                                                  Speech  \
# Year ISO-alpha3 Code
# 1970 AUT              155.\t  May I begin by expressing to Ambassado...
# 1971 AUT              112.\t  Mr. President. I am happy to convey to...
# 1972 AUT              Mr. President, I take the greatest pleasure in...
# 1973 AUT              ﻿1.\tThe twenty-eighth session of the General ...
# 1974 AUT              Sir, it is more than a mere custom, and for me...
#
#                       Global Code Global Name  Region Code Region Name  \
# Year ISO-alpha3 Code
# 1970 AUT                        1       World        150.0      Europe
# 1971 AUT                        1       World        150.0      Europe
# 1972 AUT                        1       World        150.0      Europe
# 1973 AUT                        1       World        150.0      Europe
# 1974 AUT                        1       World        150.0      Europe
#
#                       Sub-region Code Sub-region Name  \
# Year ISO-alpha3 Code
# 1970 AUT                        155.0  Western Europe
# 1971 AUT                        155.0  Western Europe
# 1972 AUT                        155.0  Western Europe
# 1973 AUT                        155.0  Western Europe
# 1974 AUT                        155.0  Western Europe
#
#                       Intermediate Region Code Intermediate Region Name  \
# Year ISO-alpha3 Code
# 1970 AUT                                   NaN                      NaN
# 1971 AUT                                   NaN                      NaN
# 1972 AUT                                   NaN                      NaN
# 1973 AUT                                   NaN                      NaN
# 1974 AUT                                   NaN                      NaN
#
#                      Country or Area  M49 Code ISO-alpha2 Code  \
# Year ISO-alpha3 Code
# 1970 AUT                     Austria        40              AT
# 1971 AUT                     Austria        40              AT
# 1972 AUT                     Austria        40              AT
# 1973 AUT                     Austria        40              AT
# 1974 AUT                     Austria        40              AT
#
#                      Least Developed Countries (LDC)  \
# Year ISO-alpha3 Code
# 1970 AUT                                         NaN
# 1971 AUT                                         NaN
# 1972 AUT                                         NaN
# 1973 AUT                                         NaN
# 1974 AUT                                         NaN
#
#                      Land Locked Developing Countries (LLDC)  \
# Year ISO-alpha3 Code
# 1970 AUT                                                 NaN
# 1971 AUT                                                 NaN
# 1972 AUT                                                 NaN
# 1973 AUT                                                 NaN
# 1974 AUT                                                 NaN
#
#                      Small Island Developing States (SIDS)
# Year ISO-alpha3 Code
# 1970 AUT                                               NaN
# 1971 AUT                                               NaN
# 1972 AUT                                               NaN
# 1973 AUT                                               NaN
# 1974 AUT                                               NaN

# %% [markdown]
# We are now going to use NLTK
#
# Please run the cell below to import NLTK and download the needed resources

# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to /Users/mayla/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/mayla/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/mayla/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# Let us now see some examples of word analysis with NLTK:
#
# Which were the most frequent words used in the Austrian Speech in 1970?

# %%
from nltk.probability import FreqDist
from nltk import word_tokenize

# load text of Austria in 1970
text = df_un_merged.loc[1970,'AUT']["Speech"]

# tokenize words
words = word_tokenize(text)

# compute word frequency
freq = FreqDist(words)

# show 30 most frequent words
freq.most_common(30)
# Out:
# [('the', 383),
#  ('of', 268),
#  (',', 180),
#  ('to', 163),
#  ('.', 160),
#  ('and', 116),
#  ('in', 104),
#  ('a', 91),
#  ('that', 55),
#  ('by', 39),
#  ('this', 39),
#  ('for', 39),
#  ('which', 38),
#  ('be', 35),
#  ('on', 34),
#  ('is', 32),
#  ('United', 30),
#  ('The', 29),
#  ('Nations', 28),
#  ('as', 27),
#  ('Austria', 26),
#  ('our', 23),
#  ('with', 23),
#  ('I', 22),
#  ('international', 22),
#  ('it', 22),
#  ('has', 21),
#  ('States', 21),
#  ('all', 20),
#  ('its', 20)]

# %% [markdown]
# **Q2: Plot the histogram with the top most used words:**

# %%
import matplotlib.pyplot as plt

top30 = freq.most_common(30)
words = [i[0]for i in top30]
counts =  [i[1]for i in top30]
plt.hist(words, weights=counts)
plt.xticks(rotation=50)
display(plt)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# Notice that the most frequent words are not that informative about the Austrian speech (the, of, to...). These words are often called *stop-words*. These words are generally filtered out before processing text (natural language). These are actually some of the most common words in any language (articles, prepositions, pronouns, conjunctions, etc) but do not add much information to the text. Let's now use NLTK to filter those words

# %%
from nltk.corpus import stopwords

def preprocess(words):
    sw = stopwords.words("english")
    no_sw = []
    for w in words:
        if (w not in sw):
            no_sw.append(w)
    return no_sw

text = df_un_merged.loc[2002,"AFG"]["Speech"]

words = word_tokenize(text)
words = preprocess(words)
freq = FreqDist(words)

freq.plot(20)
# Out:
# <AxesSubplot: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# **Q3: Can you change the method preprocess to put all words in lower case, remove punctuation and remove non-informative words (e.g., United Nations)?**
#
# Tip: the method isalpha() might be useful

# %%
from nltk.corpus import stopwords

def preprocess(words):
    sw = stopwords.words("english")
    clean = []
    for w in words:
        if (w not in sw) and (w.isalpha()):
            clean.append(str.lower(w))

    return clean

text = df_un_merged.loc[2002,"AFG"]["Speech"]

words = word_tokenize(text)
words = preprocess(words)
freq = FreqDist(words)

freq.plot(20)
# Out:
# <AxesSubplot: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# A regular expression is a sequence of characters that specifies a pattern. Usually, such patterns are used by to find, match, replace sub-strings within a document. Regular expressions have a particular syntax and are often useful to clean and pre-process textual data. Here one example where the regular expression 'afg.\*' is used to match any word that starts with afg and is followed by any character.

# %%
# Regular expression example
s = set({})
import re
for w in words:
    if re.match('afg.*n$', w):
        s.add(w)
print(s)
# Out:
# {'afghanistan', 'afghan'}

# %% [markdown]
# Another useful usage of NLTK is performing sentiment analysis.
#
# Sentiment analysis can be seen as the process of automatically classifying text into positive or negative sentiment categories. With NLTK, you can employ these algorithms without effort. This was also called opinion mining.
#
# In the political field, sentiment analysis is used to keep track of political view, to detect consistency and inconsistency between statements and actions at the government level or to derive the opinion or attitude of a speaker.
#
# NLTK implements VADER (Valence Aware Dictionary and sEntiment Reasoner), which is a lexicon and rule-based sentiment analysis. VADER uses a list of lexical features (e.g., words) which are generally labeled according to their semantic orientation as either positive or negative. VADER not only tells about the Positivity and Negativity score but also tells us about how positive or negative a sentiment is.
#
# NLTK implements VADER through the module SentimentIntensityAnalyzer. Below an example of application (with natural limitations as VADER is specifically attuned to sentiments expressed in **social media**):

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

import matplotlib.pyplot as plt

sia = SentimentIntensityAnalyzer()

vecUSA = [sia.polarity_scores(df_un_merged.loc(axis=0)[i,"USA"]["Speech"])['pos'] for i in np.arange(1971, 2021)]
vecRUS = [sia.polarity_scores(df_un_merged.loc(axis=0)[i,"RUS"]["Speech"])['pos'] for i in np.arange(1971, 2021)]
vecCHN = [sia.polarity_scores(df_un_merged.loc(axis=0)[i,"CHN"]["Speech"])['pos'] for i in np.arange(1971, 2021)]

fig, ax = plt.subplots()
ax.plot(np.arange(1971, 2021), vecUSA)
ax.plot(np.arange(1971, 2021), vecRUS)
ax.plot(np.arange(1971, 2021), vecCHN)
plt.show()

# %% [markdown]
# Notice that depending on how you're going to use the UN Debates corpus, you might need to perform some data cleaning. For example, try to execute the following code:
#
# <code>df_un_merged.loc[1970,"YUG"]</code> (too many NaN)
#
# <code>df_un_merged.loc[2020,"POR"]</code> (too many NaN)
#
# <code>df_un_merged.loc[2020,"PRT"]</code> (error)
#
# **Q4: Can you identify and solve the problems?**

# %%
df_un_merged.loc[2020,"POR"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File /usr/local/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'POR'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [105], line 1
# ----> 1 df_un_merged.loc[2020,"POR"]
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py:1068, in _LocationIndexer.__getitem__(self, key)
#    1066     if self._is_scalar_access(key):
#    1067         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1068     return self._getitem_tuple(key)
#    1069 else:
#    1070     # we by definition only have the 0th axis
#    1071     axis = self.axis or 0
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py:1248, in _LocIndexer._getitem_tuple(self, tup)
#    1246 with suppress(IndexingError):
#    1247     tup = self._expand_ellipsis(tup)
# -> 1248     return self._getitem_lowerdim(tup)
#    1250 # no multi-index, so validate all of the indexers
#    1251 tup = self._validate_tuple_indexer(tup)
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py:992, in _LocationIndexer._getitem_lowerdim(self, tup)
#     990             return section
#     991         # This is an elided recursive call to iloc/loc
# --> 992         return getattr(section, self.name)[new_key]
#     994 raise IndexingError("not applicable")
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py:1068, in _LocationIndexer.__getitem__(self, key)
#    1066     if self._is_scalar_access(key):
#    1067         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1068     return self._getitem_tuple(key)
#    1069 else:
#    1070     # we by definition only have the 0th axis
#    1071     axis = self.axis or 0
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py:1248, in _LocIndexer._getitem_tuple(self, tup)
#    1246 with suppress(IndexingError):
#    1247     tup = self._expand_ellipsis(tup)
# -> 1248     return self._getitem_lowerdim(tup)
#    1250 # no multi-index, so validate all of the indexers
#    1251 tup = self._validate_tuple_indexer(tup)
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py:968, in _LocationIndexer._getitem_lowerdim(self, tup)
#     964 for i, key in enumerate(tup):
#     965     if is_label_like(key):
#     966         # We don't need to check for tuples here because those are
#     967         #  caught by the _is_nested_tuple_indexer check above.
# --> 968         section = self._getitem_axis(key, axis=i)
#     970         # We should never have a scalar section here, because
#     971         #  _getitem_lowerdim is only called after a check for
#     972         #  is_scalar_access, which that would be.
#     973         if section.ndim == self.ndim:
#     974             # we're in the middle of slicing through a MultiIndex
#     975             # revise the key wrt to `section` by inserting an _NS
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py:1313, in _LocIndexer._getitem_axis(self, key, axis)
#    1311 # fall thru to straight lookup
#    1312 self._validate_key(key, axis)
# -> 1313 return self._get_label(key, axis=axis)
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py:1261, in _LocIndexer._get_label(self, label, axis)
#    1259 def _get_label(self, label, axis: int):
#    1260     # GH#5567 this will fail if the label is not present in the axis.
# -> 1261     return self.obj.xs(label, axis=axis)
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/generic.py:4042, in NDFrame.xs(self, key, axis, level, drop_level)
#    4040 if axis == 1:
#    4041     if drop_level:
# -> 4042         return self[key]
#    4043     index = self.columns
#    4044 else:
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 'POR'

# %%
df_un_merged.loc[2019,"POR"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File /usr/local/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'POR'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [106], line 1
# ----> 1 df_un_merged.loc[2019,"POR"]
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py:1068, in _LocationIndexer.__getitem__(self, key)
#    1066     if self._is_scalar_access(key):
#    1067         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1068     return self._getitem_tuple(key)
#    1069 else:
#    1070     # we by definition only have the 0th axis
#    1071     axis = self.axis or 0
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py:1248, in _LocIndexer._getitem_tuple(self, tup)
#    1246 with suppress(IndexingError):
#    1247     tup = self._expand_ellipsis(tup)
# -> 1248     return self._getitem_lowerdim(tup)
#    1250 # no multi-index, so validate all of the indexers
#    1251 tup = self._validate_tuple_indexer(tup)
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py:992, in _LocationIndexer._getitem_lowerdim(self, tup)
#     990             return section
#     991         # This is an elided recursive call to iloc/loc
# --> 992         return getattr(section, self.name)[new_key]
#     994 raise IndexingError("not applicable")
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py:1068, in _LocationIndexer.__getitem__(self, key)
#    1066     if self._is_scalar_access(key):
#    1067         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1068     return self._getitem_tuple(key)
#    1069 else:
#    1070     # we by definition only have the 0th axis
#    1071     axis = self.axis or 0
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py:1248, in _LocIndexer._getitem_tuple(self, tup)
#    1246 with suppress(IndexingError):
#    1247     tup = self._expand_ellipsis(tup)
# -> 1248     return self._getitem_lowerdim(tup)
#    1250 # no multi-index, so validate all of the indexers
#    1251 tup = self._validate_tuple_indexer(tup)
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py:968, in _LocationIndexer._getitem_lowerdim(self, tup)
#     964 for i, key in enumerate(tup):
#     965     if is_label_like(key):
#     966         # We don't need to check for tuples here because those are
#     967         #  caught by the _is_nested_tuple_indexer check above.
# --> 968         section = self._getitem_axis(key, axis=i)
#     970         # We should never have a scalar section here, because
#     971         #  _getitem_lowerdim is only called after a check for
#     972         #  is_scalar_access, which that would be.
#     973         if section.ndim == self.ndim:
#     974             # we're in the middle of slicing through a MultiIndex
#     975             # revise the key wrt to `section` by inserting an _NS
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py:1313, in _LocIndexer._getitem_axis(self, key, axis)
#    1311 # fall thru to straight lookup
#    1312 self._validate_key(key, axis)
# -> 1313 return self._get_label(key, axis=axis)
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexing.py:1261, in _LocIndexer._get_label(self, label, axis)
#    1259 def _get_label(self, label, axis: int):
#    1260     # GH#5567 this will fail if the label is not present in the axis.
# -> 1261     return self.obj.xs(label, axis=axis)
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/generic.py:4042, in NDFrame.xs(self, key, axis, level, drop_level)
#    4040 if axis == 1:
#    4041     if drop_level:
# -> 4042         return self[key]
#    4043     index = self.columns
#    4044 else:
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 'POR'
